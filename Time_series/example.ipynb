# %%
import pandas as pd
import numpy as np
from fbprophet import Prophet
import matplotlib.pyplot as plt

# Add this to python2 code to make life easier
from __future__ import absolute_import, division, print_function

# %%
df = pd.read_csv('./example_wp_peyton_manning.csv')
df['y'] = np.log(df['y'])
df.head()
# Out:
#            ds         y
# 0  2007-12-10  9.590761
# 1  2007-12-11  8.519590
# 2  2007-12-12  8.183677
# 3  2007-12-13  8.072467
# 4  2007-12-14  7.893572

# %%
df.plot(x='ds', y='y')
plt.show()

# %%
m = Prophet()
m.fit(df);

# %%
future = m.make_future_dataframe(periods=365)
future.tail()
# Out:
#              ds
# 3265 2017-01-15
# 3266 2017-01-16
# 3267 2017-01-17
# 3268 2017-01-18
# 3269 2017-01-19

# %%
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#              ds      yhat  yhat_lower  yhat_upper
# 3265 2017-01-15  8.200900    7.529919    8.919613
# 3266 2017-01-16  8.525905    7.791952    9.318604
# 3267 2017-01-17  8.313265    7.569395    9.042676
# 3268 2017-01-18  8.145861    7.404957    8.873163
# 3269 2017-01-19  8.157749    7.441725    8.944588

# %%
#df.plot(x='ds', y='y');
m.plot(forecast);
plt.show()

# %%
m.plot_components(forecast);
plt.show()
